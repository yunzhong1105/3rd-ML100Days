# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y , yp):
    """
    請完成這個 Function 後往下執行
    """
    
    mse = MSE = sum((y - yp) ** 2) / len(y)
    
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 241.766
# The Mean absolute error is 12.813

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 我選擇"Titanic:Machine Learning from Disaster"，由於這筆資料給的內容完整，且考慮到很多因素，故作為機器學習的教材我認為很適合初學者，另外也有系上的老師曾經指派這項作業，雖然最後沒完成，但在過程中我也慢慢的對機器學習有基礎的概念。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 無法找到資料來源，個人猜想是後人將所有上船的乘客做了身家調查，並記錄下來而得。
#
# 3. 蒐集而來的資料型態為何
#
# 檔案為csv檔，從編輯器開啟後，即使內容是數字，電腦也判定為字元。
#
# 4. 這組資料想解決的問題如何評估
#
# 這筆資料想透過一筆訓練資料設計出模型，然後把我們不知道結果的資料放進模型內並做出預測，看結果的正確率如何，我認為鐵達尼號船難乃是歷史一大憾事，倘若能透過這起事件預測出存活率，說不定能找到某些和存活率相關的因素(如：年齡、船艙等級、是否有兄弟姊妹等)，而降低往後船難的死亡人數。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 提升業績即代表減少司機等候的時間並增加一天可以載客的次數，而我認為可透過以區域的方式劃分，然後在各個區域內紀錄每天載客的總次數，並以時段、路段、客人年齡、客人人數，進而產出預測模型；另外我假設
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 我認為影響問題最多的因素為地點，舉例來說，火車站相較於任何地點，計程車的需求量一定是最大的，而同樣為火車站，大站和小站一定有所差異；至於蒐集資料我認為可透過APP的方式，推出一個新的APP用來呼叫計程車，並記錄下地點、時間等訊息，
#
# 3. 蒐集而來的資料型態為何
#
# 獲得的資料我將以list的方式儲存，並將每日載客總次數依照時間做排序，大概構思如下"[編號，地點，時間，乘客年齡，乘客人數，搭乘里程，車資，編號，地點，時間...]"，以七個元素為一組，將當日的所有乘車資料放進此陣列中，並以索引方式提出，以利做更進一步的處理。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 我打算使用此模型所預測的結果三個月，並在這期間繼續蒐集資料，獲得之後和原本的資料比較進行分析，確認看看是否有提高業績；倘若成功，則會放入更多相關因素做分析(如：觀光產業、季節、天氣、政府政策等)，繼續提升業績；若答案為否定，則暫時回到原本的方式，重新評估並想辦法導正程式。
